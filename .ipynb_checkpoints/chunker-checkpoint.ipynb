# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\tcsim\PycharmProjects\Capstone-LLM-Project-\Logs_Normal\combined_Normal.csv")

# %%
df["RowID"].is_unique
# Out:
# True

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Removing duplicates



df.duplicated().sum()
df = df.drop_duplicates()

# %%
df.iloc[0].str.len().sum()
# Out:
# np.float64(231.0)

# %%
len(df)
# Out:
# 9389

# %%
# Fixed chunker
chunk_list = []

def chunker(df):
    max_chars=15000
    context=20
    start_size=150
    total_rows = len(df)
    end = 0
    chunk_count = 0

    while end < total_rows:
        stop = min(end + start_size, total_rows)
        if end == 0:
            df_chunk = df.iloc[end:stop]
            ctx = 0
        else:
           
            df_chunk = df.iloc[max(end - context, 0):stop]
            ctx = context
        while len(df_chunk.to_string(index=False)) > max_chars and len(df_chunk) > start_size:
            df_chunk = df_chunk.iloc[:-1]  # remove last row
            stop -= 1  

        chunk_list.append(df_chunk)
        chunk_count += 1

        num_new_rows = len(df_chunk) - ctx
        if num_new_rows <= 0:
            num_new_rows = 1
        end += num_new_rows

        print(f"Chunk {chunk_count}: rows {df_chunk.index[0]} to {df_chunk.index[-1]} ({len(df_chunk)} rows)")

    print(f"Total chunks created: {chunk_count}")

# %%
chunker(df)
print("done")
# Out:
# Chunk 1: rows 0 to 149 (150 rows)
# Chunk 2: rows 130 to 279 (150 rows)
# Chunk 3: rows 260 to 409 (150 rows)
# Chunk 4: rows 390 to 539 (150 rows)
# Chunk 5: rows 520 to 669 (150 rows)
# Chunk 6: rows 650 to 799 (150 rows)
# Chunk 7: rows 780 to 929 (150 rows)
# Chunk 8: rows 910 to 1059 (150 rows)
# Chunk 9: rows 1040 to 1189 (150 rows)
# Chunk 10: rows 1170 to 1319 (150 rows)
# Chunk 11: rows 1300 to 1449 (150 rows)
# Chunk 12: rows 1430 to 1579 (150 rows)
# Chunk 13: rows 1560 to 1709 (150 rows)
# Chunk 14: rows 1690 to 1839 (150 rows)
# Chunk 15: rows 1820 to 1969 (150 rows)
# Chunk 16: rows 1950 to 2099 (150 rows)
# Chunk 17: rows 2080 to 2229 (150 rows)
# Chunk 18: rows 2210 to 2359 (150 rows)
# Chunk 19: rows 2340 to 2489 (150 rows)
# Chunk 20: rows 2470 to 2619 (150 rows)
# Chunk 21: rows 2600 to 2749 (150 rows)
# Chunk 22: rows 2730 to 2879 (150 rows)
# Chunk 23: rows 2860 to 3009 (150 rows)
# Chunk 24: rows 2990 to 3139 (150 rows)
# Chunk 25: rows 3120 to 3269 (150 rows)
# Chunk 26: rows 3250 to 3399 (150 rows)
# Chunk 27: rows 3380 to 3529 (150 rows)
# Chunk 28: rows 3510 to 3659 (150 rows)
# Chunk 29: rows 3640 to 3789 (150 rows)
# Chunk 30: rows 3770 to 3919 (150 rows)
# Chunk 31: rows 3900 to 4049 (150 rows)
# Chunk 32: rows 4030 to 4179 (150 rows)
# Chunk 33: rows 4160 to 4309 (150 rows)
# Chunk 34: rows 4290 to 4439 (150 rows)
# Chunk 35: rows 4420 to 4569 (150 rows)
# Chunk 36: rows 4550 to 4699 (150 rows)
# Chunk 37: rows 4680 to 4829 (150 rows)
# Chunk 38: rows 4810 to 4959 (150 rows)
# Chunk 39: rows 4940 to 5089 (150 rows)
# Chunk 40: rows 5070 to 5219 (150 rows)
# Chunk 41: rows 5200 to 5349 (150 rows)
# Chunk 42: rows 5330 to 5479 (150 rows)
# Chunk 43: rows 5460 to 5609 (150 rows)
# Chunk 44: rows 5590 to 5739 (150 rows)
# Chunk 45: rows 5720 to 5869 (150 rows)
# Chunk 46: rows 5850 to 5999 (150 rows)
# Chunk 47: rows 5980 to 6129 (150 rows)
# Chunk 48: rows 6110 to 6259 (150 rows)
# Chunk 49: rows 6240 to 6389 (150 rows)
# Chunk 50: rows 6370 to 6519 (150 rows)
# Chunk 51: rows 6500 to 6649 (150 rows)
# Chunk 52: rows 6630 to 6779 (150 rows)
# Chunk 53: rows 6760 to 6909 (150 rows)
# Chunk 54: rows 6890 to 7039 (150 rows)
# Chunk 55: rows 7020 to 7169 (150 rows)
# Chunk 56: rows 7150 to 7299 (150 rows)
# Chunk 57: rows 7280 to 7429 (150 rows)
# Chunk 58: rows 7410 to 7559 (150 rows)
# Chunk 59: rows 7540 to 7689 (150 rows)
# Chunk 60: rows 7670 to 7819 (150 rows)
# Chunk 61: rows 7800 to 7949 (150 rows)
# Chunk 62: rows 7930 to 8079 (150 rows)
# Chunk 63: rows 8060 to 8209 (150 rows)
# Chunk 64: rows 8190 to 8339 (150 rows)
# Chunk 65: rows 8320 to 8469 (150 rows)
# Chunk 66: rows 8450 to 8599 (150 rows)
# Chunk 67: rows 8580 to 8729 (150 rows)
# Chunk 68: rows 8710 to 8859 (150 rows)
# Chunk 69: rows 8840 to 8989 (150 rows)
# Chunk 70: rows 8970 to 9119 (150 rows)
# Chunk 71: rows 9100 to 9249 (150 rows)
# Chunk 72: rows 9230 to 9379 (150 rows)
# Chunk 73: rows 9360 to 9509 (150 rows)
# Chunk 74: rows 9490 to 9639 (150 rows)
# Chunk 75: rows 9620 to 9769 (150 rows)
# Chunk 76: rows 9750 to 9899 (150 rows)
# Chunk 77: rows 9880 to 10029 (150 rows)
# Chunk 78: rows 10010 to 10159 (150 rows)
# Chunk 79: rows 10140 to 10289 (150 rows)
# Chunk 80: rows 10270 to 10419 (150 rows)
# Chunk 81: rows 10400 to 10549 (150 rows)
# Chunk 82: rows 10530 to 10679 (150 rows)
# Chunk 83: rows 10660 to 10809 (150 rows)
# Chunk 84: rows 10790 to 10939 (150 rows)
# Chunk 85: rows 10920 to 11069 (150 rows)
# Chunk 86: rows 11050 to 11199 (150 rows)
# Chunk 87: rows 11180 to 11329 (150 rows)
# Chunk 88: rows 11310 to 11459 (150 rows)
# Chunk 89: rows 11440 to 11589 (150 rows)
# Chunk 90: rows 11570 to 11719 (150 rows)
# Chunk 91: rows 11700 to 11849 (150 rows)
# Chunk 92: rows 11830 to 11979 (150 rows)
# Chunk 93: rows 11960 to 12109 (150 rows)
# Chunk 94: rows 12090 to 12239 (150 rows)
# Chunk 95: rows 12220 to 12369 (150 rows)
# Chunk 96: rows 12350 to 12499 (150 rows)
# Chunk 97: rows 12480 to 12629 (150 rows)
# Chunk 98: rows 12610 to 12759 (150 rows)
# Chunk 99: rows 12740 to 12889 (150 rows)
# Chunk 100: rows 12870 to 13019 (150 rows)
# Chunk 101: rows 13000 to 13149 (150 rows)
# Chunk 102: rows 13130 to 13279 (150 rows)
# Chunk 103: rows 13260 to 13409 (150 rows)
# Chunk 104: rows 13390 to 13539 (150 rows)
# Chunk 105: rows 13520 to 13669 (150 rows)
# Chunk 106: rows 13650 to 13799 (150 rows)
# Chunk 107: rows 13780 to 13929 (150 rows)
# Chunk 108: rows 13910 to 14059 (150 rows)
# Chunk 109: rows 14040 to 14189 (150 rows)
# Chunk 110: rows 14170 to 14319 (150 rows)
# Chunk 111: rows 14300 to 14449 (150 rows)
# Chunk 112: rows 14430 to 14579 (150 rows)
# Chunk 113: rows 14560 to 14709 (150 rows)
# Chunk 114: rows 14690 to 14839 (150 rows)
# Chunk 115: rows 14820 to 14969 (150 rows)
# Chunk 116: rows 14950 to 15099 (150 rows)
# Chunk 117: rows 15080 to 15229 (150 rows)
# Chunk 118: rows 15210 to 15359 (150 rows)
# Chunk 119: rows 15340 to 15489 (150 rows)
# Chunk 120: rows 15470 to 15548 (79 rows)
# Total chunks created: 120
# done

# %%
# check
all_rows = pd.concat(chunk_list, ignore_index=True)

# Count unique rows by RecordNumber
unique_rows = all_rows['RecordNumber'].nunique()
test1 = df['RecordNumber'].nunique()
print(f"Unique rows: {test1}")  # should match original 9389
print(f"Unique rows: {unique_rows}")  # should match original 9389
# Out:
# Unique rows: 14145
# Unique rows: 14145

# %%
# Out:
# Original rows: 15549
# Chunked rows: 17929
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 17
#      15 print(f"Original rows: {total_original}")
#      16 print(f"Chunked rows: {total_chunked}")
# ---> 17 assert total_original == total_chunked, "Some rows were skipped!"
#      19 # -------------------------------
#      20 # 2. Check context overlap
#      21 # -------------------------------
#      22 for i in range(1, len(chunk_list)):
#
# AssertionError: Some rows were skipped!

# %%
# Out:
# Unique rows: 14145
# Unique rows: 14145

# %%
# Out:
# Original unique rows: 9084

# %%
chunk_list
# Out:
# []

# %%
start = 1
for chunk in chunk_list:
    chunk.to_csv(
        rf"Logs_Normal\D_Chunked_normal\chunk{start}.csv",
        index=False
    )
    start += 1

print("done")
# Out:
# done

# %%
df.to_csv('clean_data.csv')

# %%
df.loc[0:1]
