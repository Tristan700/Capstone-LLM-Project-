# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\tcsim\PycharmProjects\Capstone-LLM-Project-\Logs_Normal\combined_Normal.csv")

# %%
df["RowID"].is_unique
# Out:
# True

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Removing duplicates



df.duplicated().sum()
df = df.drop_duplicates()

# %%
df.iloc[0].str.len().sum()
# Out:
# np.float64(231.0)

# %%
len(df)
# Out:
# 9389

# %%
# Fixed chunker
chunk_list = []

def chunker(df):
    max_chars=15000
    context=10
    start_size=80
    total_rows = len(df)
    end = 0
    chunk_count = 0

    while end < total_rows:
        stop = min(end + start_size, total_rows)
        if end == 0:
            df_chunk = df.iloc[end:stop]
            ctx = 0
        else:
           
            df_chunk = df.iloc[max(end - context, 0):stop]
            ctx = context
        while len(df_chunk.to_string(index=False)) > max_chars and len(df_chunk) > start_size:
            df_chunk = df_chunk.iloc[:-1]  # remove last row
            stop -= 1  

        chunk_list.append(df_chunk)
        chunk_count += 1

        num_new_rows = len(df_chunk) - ctx
        if num_new_rows <= 0:
            num_new_rows = 1
        end += num_new_rows

        print(f"Chunk {chunk_count}: rows {df_chunk.index[0]} to {df_chunk.index[-1]} ({len(df_chunk)} rows)")

    print(f"Total chunks created: {chunk_count}")

# %%
chunker(df)
print("done")
# Out:
# Chunk 1: rows 0 to 79 (80 rows)
# Chunk 2: rows 70 to 149 (80 rows)
# Chunk 3: rows 140 to 219 (80 rows)
# Chunk 4: rows 210 to 289 (80 rows)
# Chunk 5: rows 280 to 359 (80 rows)
# Chunk 6: rows 350 to 429 (80 rows)
# Chunk 7: rows 420 to 499 (80 rows)
# Chunk 8: rows 490 to 569 (80 rows)
# Chunk 9: rows 560 to 639 (80 rows)
# Chunk 10: rows 630 to 709 (80 rows)
# Chunk 11: rows 700 to 779 (80 rows)
# Chunk 12: rows 770 to 849 (80 rows)
# Chunk 13: rows 840 to 919 (80 rows)
# Chunk 14: rows 910 to 989 (80 rows)
# Chunk 15: rows 980 to 1059 (80 rows)
# Chunk 16: rows 1050 to 1129 (80 rows)
# Chunk 17: rows 1120 to 1199 (80 rows)
# Chunk 18: rows 1190 to 1269 (80 rows)
# Chunk 19: rows 1260 to 1339 (80 rows)
# Chunk 20: rows 1330 to 1409 (80 rows)
# Chunk 21: rows 1400 to 1479 (80 rows)
# Chunk 22: rows 1470 to 1549 (80 rows)
# Chunk 23: rows 1540 to 1619 (80 rows)
# Chunk 24: rows 1610 to 1689 (80 rows)
# Chunk 25: rows 1680 to 1759 (80 rows)
# Chunk 26: rows 1750 to 1829 (80 rows)
# Chunk 27: rows 1820 to 1899 (80 rows)
# Chunk 28: rows 1890 to 1969 (80 rows)
# Chunk 29: rows 1960 to 2039 (80 rows)
# Chunk 30: rows 2030 to 2109 (80 rows)
# Chunk 31: rows 2100 to 2179 (80 rows)
# Chunk 32: rows 2170 to 2249 (80 rows)
# Chunk 33: rows 2240 to 2319 (80 rows)
# Chunk 34: rows 2310 to 2389 (80 rows)
# Chunk 35: rows 2380 to 2459 (80 rows)
# Chunk 36: rows 2450 to 2529 (80 rows)
# Chunk 37: rows 2520 to 2599 (80 rows)
# Chunk 38: rows 2590 to 2669 (80 rows)
# Chunk 39: rows 2660 to 2739 (80 rows)
# Chunk 40: rows 2730 to 2809 (80 rows)
# Chunk 41: rows 2800 to 2879 (80 rows)
# Chunk 42: rows 2870 to 2949 (80 rows)
# Chunk 43: rows 2940 to 3019 (80 rows)
# Chunk 44: rows 3010 to 3089 (80 rows)
# Chunk 45: rows 3080 to 3159 (80 rows)
# Chunk 46: rows 3150 to 3229 (80 rows)
# Chunk 47: rows 3220 to 3299 (80 rows)
# Chunk 48: rows 3290 to 3369 (80 rows)
# Chunk 49: rows 3360 to 3439 (80 rows)
# Chunk 50: rows 3430 to 3509 (80 rows)
# Chunk 51: rows 3500 to 3579 (80 rows)
# Chunk 52: rows 3570 to 3649 (80 rows)
# Chunk 53: rows 3640 to 3719 (80 rows)
# Chunk 54: rows 3710 to 3789 (80 rows)
# Chunk 55: rows 3780 to 3859 (80 rows)
# Chunk 56: rows 3850 to 3929 (80 rows)
# Chunk 57: rows 3920 to 3999 (80 rows)
# Chunk 58: rows 3990 to 4069 (80 rows)
# Chunk 59: rows 4060 to 4139 (80 rows)
# Chunk 60: rows 4130 to 4209 (80 rows)
# Chunk 61: rows 4200 to 4279 (80 rows)
# Chunk 62: rows 4270 to 4349 (80 rows)
# Chunk 63: rows 4340 to 4419 (80 rows)
# Chunk 64: rows 4410 to 4489 (80 rows)
# Chunk 65: rows 4480 to 4559 (80 rows)
# Chunk 66: rows 4550 to 4629 (80 rows)
# Chunk 67: rows 4620 to 4699 (80 rows)
# Chunk 68: rows 4690 to 4769 (80 rows)
# Chunk 69: rows 4760 to 4839 (80 rows)
# Chunk 70: rows 4830 to 4909 (80 rows)
# Chunk 71: rows 4900 to 4979 (80 rows)
# Chunk 72: rows 4970 to 5049 (80 rows)
# Chunk 73: rows 5040 to 5119 (80 rows)
# Chunk 74: rows 5110 to 5189 (80 rows)
# Chunk 75: rows 5180 to 5259 (80 rows)
# Chunk 76: rows 5250 to 5329 (80 rows)
# Chunk 77: rows 5320 to 5399 (80 rows)
# Chunk 78: rows 5390 to 5469 (80 rows)
# Chunk 79: rows 5460 to 5539 (80 rows)
# Chunk 80: rows 5530 to 5609 (80 rows)
# Chunk 81: rows 5600 to 5679 (80 rows)
# Chunk 82: rows 5670 to 5749 (80 rows)
# Chunk 83: rows 5740 to 5819 (80 rows)
# Chunk 84: rows 5810 to 5889 (80 rows)
# Chunk 85: rows 5880 to 5959 (80 rows)
# Chunk 86: rows 5950 to 6029 (80 rows)
# Chunk 87: rows 6020 to 6099 (80 rows)
# Chunk 88: rows 6090 to 6169 (80 rows)
# Chunk 89: rows 6160 to 6239 (80 rows)
# Chunk 90: rows 6230 to 6309 (80 rows)
# Chunk 91: rows 6300 to 6379 (80 rows)
# Chunk 92: rows 6370 to 6449 (80 rows)
# Chunk 93: rows 6440 to 6519 (80 rows)
# Chunk 94: rows 6510 to 6589 (80 rows)
# Chunk 95: rows 6580 to 6659 (80 rows)
# Chunk 96: rows 6650 to 6729 (80 rows)
# Chunk 97: rows 6720 to 6799 (80 rows)
# Chunk 98: rows 6790 to 6869 (80 rows)
# Chunk 99: rows 6860 to 6939 (80 rows)
# Chunk 100: rows 6930 to 7009 (80 rows)
# Chunk 101: rows 7000 to 7079 (80 rows)
# Chunk 102: rows 7070 to 7149 (80 rows)
# Chunk 103: rows 7140 to 7219 (80 rows)
# Chunk 104: rows 7210 to 7289 (80 rows)
# Chunk 105: rows 7280 to 7359 (80 rows)
# Chunk 106: rows 7350 to 7429 (80 rows)
# Chunk 107: rows 7420 to 7499 (80 rows)
# Chunk 108: rows 7490 to 7569 (80 rows)
# Chunk 109: rows 7560 to 7639 (80 rows)
# Chunk 110: rows 7630 to 7709 (80 rows)
# Chunk 111: rows 7700 to 7779 (80 rows)
# Chunk 112: rows 7770 to 7849 (80 rows)
# Chunk 113: rows 7840 to 7919 (80 rows)
# Chunk 114: rows 7910 to 7989 (80 rows)
# Chunk 115: rows 7980 to 8059 (80 rows)
# Chunk 116: rows 8050 to 8129 (80 rows)
# Chunk 117: rows 8120 to 8199 (80 rows)
# Chunk 118: rows 8190 to 8269 (80 rows)
# Chunk 119: rows 8260 to 8339 (80 rows)
# Chunk 120: rows 8330 to 8409 (80 rows)
# Chunk 121: rows 8400 to 8479 (80 rows)
# Chunk 122: rows 8470 to 8549 (80 rows)
# Chunk 123: rows 8540 to 8619 (80 rows)
# Chunk 124: rows 8610 to 8689 (80 rows)
# Chunk 125: rows 8680 to 8759 (80 rows)
# Chunk 126: rows 8750 to 8829 (80 rows)
# Chunk 127: rows 8820 to 8899 (80 rows)
# Chunk 128: rows 8890 to 8969 (80 rows)
# Chunk 129: rows 8960 to 9039 (80 rows)
# Chunk 130: rows 9030 to 9109 (80 rows)
# Chunk 131: rows 9100 to 9179 (80 rows)
# Chunk 132: rows 9170 to 9249 (80 rows)
# Chunk 133: rows 9240 to 9319 (80 rows)
# Chunk 134: rows 9310 to 9389 (80 rows)
# Chunk 135: rows 9380 to 9459 (80 rows)
# Chunk 136: rows 9450 to 9529 (80 rows)
# Chunk 137: rows 9520 to 9599 (80 rows)
# Chunk 138: rows 9590 to 9669 (80 rows)
# Chunk 139: rows 9660 to 9739 (80 rows)
# Chunk 140: rows 9730 to 9809 (80 rows)
# Chunk 141: rows 9800 to 9879 (80 rows)
# Chunk 142: rows 9870 to 9949 (80 rows)
# Chunk 143: rows 9940 to 10019 (80 rows)
# Chunk 144: rows 10010 to 10089 (80 rows)
# Chunk 145: rows 10080 to 10159 (80 rows)
# Chunk 146: rows 10150 to 10229 (80 rows)
# Chunk 147: rows 10220 to 10299 (80 rows)
# Chunk 148: rows 10290 to 10369 (80 rows)
# Chunk 149: rows 10360 to 10439 (80 rows)
# Chunk 150: rows 10430 to 10509 (80 rows)
# Chunk 151: rows 10500 to 10579 (80 rows)
# Chunk 152: rows 10570 to 10649 (80 rows)
# Chunk 153: rows 10640 to 10719 (80 rows)
# Chunk 154: rows 10710 to 10789 (80 rows)
# Chunk 155: rows 10780 to 10859 (80 rows)
# Chunk 156: rows 10850 to 10929 (80 rows)
# Chunk 157: rows 10920 to 10999 (80 rows)
# Chunk 158: rows 10990 to 11069 (80 rows)
# Chunk 159: rows 11060 to 11139 (80 rows)
# Chunk 160: rows 11130 to 11209 (80 rows)
# Chunk 161: rows 11200 to 11279 (80 rows)
# Chunk 162: rows 11270 to 11349 (80 rows)
# Chunk 163: rows 11340 to 11419 (80 rows)
# Chunk 164: rows 11410 to 11489 (80 rows)
# Chunk 165: rows 11480 to 11559 (80 rows)
# Chunk 166: rows 11550 to 11629 (80 rows)
# Chunk 167: rows 11620 to 11699 (80 rows)
# Chunk 168: rows 11690 to 11769 (80 rows)
# Chunk 169: rows 11760 to 11839 (80 rows)
# Chunk 170: rows 11830 to 11909 (80 rows)
# Chunk 171: rows 11900 to 11979 (80 rows)
# Chunk 172: rows 11970 to 12049 (80 rows)
# Chunk 173: rows 12040 to 12119 (80 rows)
# Chunk 174: rows 12110 to 12189 (80 rows)
# Chunk 175: rows 12180 to 12259 (80 rows)
# Chunk 176: rows 12250 to 12329 (80 rows)
# Chunk 177: rows 12320 to 12399 (80 rows)
# Chunk 178: rows 12390 to 12469 (80 rows)
# Chunk 179: rows 12460 to 12539 (80 rows)
# Chunk 180: rows 12530 to 12609 (80 rows)
# Chunk 181: rows 12600 to 12679 (80 rows)
# Chunk 182: rows 12670 to 12749 (80 rows)
# Chunk 183: rows 12740 to 12819 (80 rows)
# Chunk 184: rows 12810 to 12889 (80 rows)
# Chunk 185: rows 12880 to 12959 (80 rows)
# Chunk 186: rows 12950 to 13029 (80 rows)
# Chunk 187: rows 13020 to 13099 (80 rows)
# Chunk 188: rows 13090 to 13169 (80 rows)
# Chunk 189: rows 13160 to 13239 (80 rows)
# Chunk 190: rows 13230 to 13309 (80 rows)
# Chunk 191: rows 13300 to 13379 (80 rows)
# Chunk 192: rows 13370 to 13449 (80 rows)
# Chunk 193: rows 13440 to 13519 (80 rows)
# Chunk 194: rows 13510 to 13589 (80 rows)
# Chunk 195: rows 13580 to 13659 (80 rows)
# Chunk 196: rows 13650 to 13729 (80 rows)
# Chunk 197: rows 13720 to 13799 (80 rows)
# Chunk 198: rows 13790 to 13869 (80 rows)
# Chunk 199: rows 13860 to 13939 (80 rows)
# Chunk 200: rows 13930 to 14009 (80 rows)
# Chunk 201: rows 14000 to 14079 (80 rows)
# Chunk 202: rows 14070 to 14149 (80 rows)
# Chunk 203: rows 14140 to 14219 (80 rows)
# Chunk 204: rows 14210 to 14289 (80 rows)
# Chunk 205: rows 14280 to 14359 (80 rows)
# Chunk 206: rows 14350 to 14429 (80 rows)
# Chunk 207: rows 14420 to 14499 (80 rows)
# Chunk 208: rows 14490 to 14569 (80 rows)
# Chunk 209: rows 14560 to 14639 (80 rows)
# Chunk 210: rows 14630 to 14709 (80 rows)
# Chunk 211: rows 14700 to 14779 (80 rows)
# Chunk 212: rows 14770 to 14849 (80 rows)
# Chunk 213: rows 14840 to 14919 (80 rows)
# Chunk 214: rows 14910 to 14989 (80 rows)
# Chunk 215: rows 14980 to 15059 (80 rows)
# Chunk 216: rows 15050 to 15129 (80 rows)
# Chunk 217: rows 15120 to 15199 (80 rows)
# Chunk 218: rows 15190 to 15269 (80 rows)
# Chunk 219: rows 15260 to 15339 (80 rows)
# Chunk 220: rows 15330 to 15409 (80 rows)
# Chunk 221: rows 15400 to 15479 (80 rows)
# Chunk 222: rows 15470 to 15548 (79 rows)
# Total chunks created: 222
# done

# %%
all_rows = pd.concat(chunk_list, ignore_index=True)
unique_rows = all_rows['RecordNumber'].nunique()
test1 = df['RecordNumber'].nunique()
print(f"Unique rows: {test1}") 
print(f"Unique rows: {unique_rows}")
# Out:
# Unique rows: 14145
# Unique rows: 14145

# %%
# Out:
# Unique rows: 14145
# Unique rows: 14145

# %%
# Out:
# Original unique rows: 9084

# %%
chunk_list
# Out:
# []

# %%
start = 1
for chunk in chunk_list:
    chunk.to_csv(
        rf"Logs_Normal\D_Chunked_normal\chunk{start}.csv",
        index=False
    )
    start += 1

print("done")
# Out:
# done

# %%
df.to_csv('clean_data.csv')

# %%
df.loc[0:1]
