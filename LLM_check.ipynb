# %%
import pandas as pd

df = pd.read_csv("Top5_Suspicious_LogsDataset1.csv")
# Out:
#                                             Full_Log  Suspicion_Score  \
# 0  {'RecordNumber': 1, 'EventID': 1102, 'Timestam...                9
#
#                                       Why_Suspicious  \
# 0  Event ID 1102 indicates clearing of the securi...
#
#                                          Explanation
# 0  Clearing security logs is a common tactic used...

# %%
df.columns
# Out:
# Index(['Full_Log', 'Suspicion_Score', 'Why_Suspicious', 'Explanation'], dtype='str')

# %%
# Out:
# 0    Clearing security logs is a common tactic used...
# 1    The process 'plink.exe' is a known SSH client ...
# 2    The log shows plink.exe running on a user desk...
# 3    EventID 4672 indicates assignment of sensitive...
# 4    plink.exe is typically used for SSH connection...
# Name: Explanation, dtype: str
